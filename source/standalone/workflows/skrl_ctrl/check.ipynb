# %%
from omni.isaac.lab_tasks.direct.quadcopter.quadcopter_env import QuadcopterTrajectoryTrainingActiveBOTaskEnvCfg
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from omni.isaac.lab_tasks.direct.quadcopter.quadcopter_env import QuadcopterTrajectoryTrainingActiveBOTaskEnvCfg
#
# File ~/PycharmProjects/IsaacLab/source/extensions/omni.isaac.lab_tasks/omni/isaac/lab_tasks/__init__.py:25
#      19 __version__ = ISAACLAB_TASKS_METADATA["package"]["version"]
#      21 ##
#      22 # Register Gym environments.
#      23 ##
# ---> 25 from .utils import import_packages
#      27 # The blacklist is used to prevent importing configs from sub-packages
#      28 _BLACKLIST_PKGS = ["utils"]
#
# File ~/PycharmProjects/IsaacLab/source/extensions/omni.isaac.lab_tasks/omni/isaac/lab_tasks/utils/__init__.py:9
#       6 """Sub-package with utilities, data collectors and environment wrappers."""
#       8 from .importer import import_packages
# ----> 9 from .parse_cfg import get_checkpoint_path, load_cfg_from_registry, parse_env_cfg
#
# File ~/PycharmProjects/IsaacLab/source/extensions/omni.isaac.lab_tasks/omni/isaac/lab_tasks/utils/parse_cfg.py:16
#      13 import re
#      14 import yaml
# ---> 16 from omni.isaac.lab.envs import DirectRLEnvCfg, ManagerBasedRLEnvCfg
#      19 def load_cfg_from_registry(task_name: str, entry_point_key: str) -> dict | object:
#      20     """Load default configuration given its entry point from the gym registry.
#      21
#      22     This function loads the configuration object from the gym registry for the given task name.
#    (...)
#      52         ValueError: If the entry point key is not available in the gym registry for the task.
#      53     """
#
# File ~/PycharmProjects/IsaacLab/source/extensions/omni.isaac.lab/omni/isaac/lab/envs/__init__.py:45
#       1 # Copyright (c) 2022-2024, The Isaac Lab Project Developers.
#       2 # All rights reserved.
#       3 #
#       4 # SPDX-License-Identifier: BSD-3-Clause
#       6 """Sub-package for environment definitions.
#       7
#       8 Environments define the interface between the agent and the simulation.
#    (...)
#      42 .. _`Task Design Workflows`: https://isaac-sim.github.io/IsaacLab/source/features/task_workflows.html
#      43 """
# ---> 45 from . import mdp, ui
#      46 from .common import VecEnvObs, VecEnvStepReturn, ViewerCfg
#      47 from .direct_marl_env import DirectMARLEnv
#
# File ~/PycharmProjects/IsaacLab/source/extensions/omni.isaac.lab/omni/isaac/lab/envs/mdp/__init__.py:18
#       1 # Copyright (c) 2022-2024, The Isaac Lab Project Developers.
#       2 # All rights reserved.
#       3 #
#       4 # SPDX-License-Identifier: BSD-3-Clause
#       6 """Sub-module with implementation of manager terms.
#       7
#       8 The functions can be provided to different managers that are responsible for the
#    (...)
#      15
#      16 """
# ---> 18 from .actions import *  # noqa: F401, F403
#      19 from .commands import *  # noqa: F401, F403
#      20 from .curriculums import *  # noqa: F401, F403
#
# File ~/PycharmProjects/IsaacLab/source/extensions/omni.isaac.lab/omni/isaac/lab/envs/mdp/actions/__init__.py:8
#       1 # Copyright (c) 2022-2024, The Isaac Lab Project Developers.
#       2 # All rights reserved.
#       3 #
#       4 # SPDX-License-Identifier: BSD-3-Clause
#       6 """Various action terms that can be used in the environment."""
# ----> 8 from .actions_cfg import *
#       9 from .binary_joint_actions import *
#      10 from .joint_actions import *
#
# File ~/PycharmProjects/IsaacLab/source/extensions/omni.isaac.lab/omni/isaac/lab/envs/mdp/actions/actions_cfg.py:9
#       6 from dataclasses import MISSING
#       8 from omni.isaac.lab.controllers import DifferentialIKControllerCfg
# ----> 9 from omni.isaac.lab.managers.action_manager import ActionTerm, ActionTermCfg
#      10 from omni.isaac.lab.utils import configclass
#      12 from . import binary_joint_actions, joint_actions, joint_actions_to_limits, non_holonomic_actions, task_space_actions
#
# File ~/PycharmProjects/IsaacLab/source/extensions/omni.isaac.lab/omni/isaac/lab/managers/__init__.py:13
#       1 # Copyright (c) 2022-2024, The Isaac Lab Project Developers.
#       2 # All rights reserved.
#       3 #
#       4 # SPDX-License-Identifier: BSD-3-Clause
#       6 """Sub-module for environment managers.
#       7
#       8 The managers are used to handle various aspects of the environment such as randomization events, curriculum,
#       9 and observations. Each manager implements a specific functionality for the environment. The managers are
#      10 designed to be modular and can be easily extended to support new functionality.
#      11 """
# ---> 13 from .action_manager import ActionManager, ActionTerm
#      14 from .command_manager import CommandManager, CommandTerm
#      15 from .curriculum_manager import CurriculumManager
#
# File ~/PycharmProjects/IsaacLab/source/extensions/omni.isaac.lab/omni/isaac/lab/managers/action_manager.py:18
#      15 from prettytable import PrettyTable
#      16 from typing import TYPE_CHECKING
# ---> 18 import omni.kit.app
#      20 from omni.isaac.lab.assets import AssetBase
#      22 from .manager_base import ManagerBase, ManagerTermBase
#
# ModuleNotFoundError: No module named 'omni.kit'
